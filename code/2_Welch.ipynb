# %% [markdown]
# # Welch Algorithm
#
# A small factory consists of a machining center and inspection station
# in series. Unfinished parts arrive to the factory with exponential
# interarrival times having a mean of 1 minute. Processing times at the machine are uni-
# form on the interval [0.65, 0.70] minute, and subsequent inspection times at the inspection
# station are uniform on the interval [0.75, 0.80] minute. Ninety percent of inspected parts
# are “good” and are sent to shipping; 10 percent of the parts are “bad” and are sent back
# to the machine for rework. (Both queues are assumed to have infinite capacity.) The
# machining center is subject to randomly occurring breakdowns. In particular, a new (or
# freshly repaired) machine will break down after an exponential amount of calendar
# time with a mean of 6 hours. Repair times are uniform on the interval
# [8, 12] minutes. If a part is being processed when the machine breaks down, then the
# machine continues where it left off upon the completion of repair. Assume that the factory
# is initially empty and idle, and is open 8 hours per day.
# Consider the stochastic process N1, N2, . . . , where Ni is the number of parts pro-
# duced in the ith hour.

# %%
import simpy
import random

class Factory:
    def __init__(self, env):
        self.env = env
        self.machine = simpy.Resource(env, capacity=1)  # Machining center
        self.inspection_station = simpy.Resource(env, capacity=1)  # Inspection station
        self.parts_produced = 0
        self.breakdown_event = env.event()

    def machining(self, part_id):
        with self.machine.request() as req:
            yield req
            machining_time = random.uniform(MACHINE_TIME_LOW, MACHINE_TIME_HIGH)
            try:
                print(f"Part {part_id}: starts machining at {env.now:.2f}")
                yield env.timeout(machining_time)
                print(f"Part {part_id}: finishes machining at {env.now:.2f}")
            except simpy.Interrupt:
                print(f"Part {part_id}: machine breakdown during machining at {env.now:.2f}")
                repair_time = random.uniform(REPAIR_TIME_LOW, REPAIR_TIME_HIGH)
                yield env.timeout(repair_time)
                print(f"Part {part_id}: machine repaired, resuming machining at {env.now:.2f}")
                yield env.timeout(machining_time - (env.now - self.env.now))

    def inspect(self, part_id):
        with self.inspection_station.request() as req:
            yield req
            inspection_time = random.uniform(INSPECTION_TIME_LOW, INSPECTION_TIME_HIGH)
            print(f"Part {part_id}: starts inspection at {env.now:.2f}")
            yield env.timeout(inspection_time)
            print(f"Part {part_id}: finishes inspection at {env.now:.2f}")

    def process_part(self, part_id):
        # Machining step
        yield env.process(self.machining(part_id))
        
        # Inspection step
        yield env.process(self.inspect(part_id))
        
        # Determine if the part needs rework
        if random.random() < REWORK_PROBABILITY:
            print(f"Part {part_id}: sent back for rework at {env.now:.2f}")
            yield env.process(self.machining(part_id))
            yield env.process(self.inspect(part_id))
        
        # Part is finally good
        self.parts_produced += 1
        print(f"Part {part_id}: good part produced at {env.now:.2f}")

def arrival_process(env, factory):
    part_id = 0
    while True:
        interarrival_time = random.expovariate(1.0 / MEAN_INTERARRIVAL)
        yield env.timeout(interarrival_time)
        part_id += 1
        env.process(factory.process_part(part_id))

def machine_breakdown(env, factory):
    while True:
        breakdown_time = random.expovariate(1.0 / BREAKDOWN_MEAN)
        yield env.timeout(breakdown_time)
        print(f"Machine breaks down at {env.now:.2f}")
        factory.breakdown_event.succeed()
        factory.breakdown_event = env.event()

def track_hourly_production(env, factory):
    while True:
        yield env.timeout(60)  # 1 hour
        hourly_production.append(factory.parts_produced)
        print(f"Hour {len(hourly_production)}: {factory.parts_produced} parts produced.")
        factory.parts_produced = 0  # Reset for the next hour

# %%
# Define constants
MEAN_INTERARRIVAL = 1.0  # Mean interarrival time in minutes
MACHINE_TIME_LOW = 0.65  # Min machine processing time
MACHINE_TIME_HIGH = 0.70  # Max machine processing time
INSPECTION_TIME_LOW = 0.75  # Min inspection time
INSPECTION_TIME_HIGH = 0.80  # Max inspection time
REWORK_PROBABILITY = 0.10  # Probability that a part is bad and requires rework
BREAKDOWN_MEAN = 360  # Mean time for machine breakdown in minutes
REPAIR_TIME_LOW = 8  # Min repair time in minutes
REPAIR_TIME_HIGH = 12  # Max repair time in minutes
WORK_DAY = 8 * 60  # Factory workday length in minutes (8 hours)

# Global variables to track the number of parts produced each hour
hourly_production = []

# Set up the simulation
random.seed(42)  # For reproducibility
env = simpy.Environment()

# Initialize the factory
factory = Factory(env)

# Start processes
env.process(arrival_process(env, factory))
env.process(machine_breakdown(env, factory))
env.process(track_hourly_production(env, factory))

# Run the simulation for 8 hours (480 minutes)
env.run(until=WORK_DAY)

# Print final results
print("Hourly production counts:", hourly_production)
# Out:
# Part 1: starts machining at 1.02
# Part 1: finishes machining at 1.68
# Part 2: starts machining at 1.68
# Part 1: starts inspection at 1.68
# Part 2: finishes machining at 2.37
# Part 1: finishes inspection at 2.48
# Part 1: sent back for rework at 2.48
# Part 2: starts inspection at 2.48
# Part 1: starts machining at 2.48
# Part 1: finishes machining at 3.13
# Part 3: starts machining at 3.13
# Part 2: finishes inspection at 3.25
# Part 2: good part produced at 3.25
# Part 1: starts inspection at 3.25
# Part 3: finishes machining at 3.78
# Part 4: starts machining at 3.78
# Part 1: finishes inspection at 4.03
# Part 1: good part produced at 4.03
# Part 3: starts inspection at 4.03
# Part 4: finishes machining at 4.44
# Part 5: starts machining at 4.44
# Part 3: finishes inspection at 4.81
# Part 3: good part produced at 4.81
# Part 4: starts inspection at 4.81
# Part 5: finishes machining at 5.09
# Part 6: starts machining at 5.09
# Part 4: finishes inspection at 5.59
# Part 4: good part produced at 5.59
# Part 5: starts inspection at 5.59
# Part 6: finishes machining at 5.76
# Part 7: starts machining at 6.07
# Part 5: finishes inspection at 6.39
# Part 5: sent back for rework at 6.39
# Part 6: starts inspection at 6.39
# Part 7: finishes machining at 6.73
# Part 5: starts machining at 6.73
# Part 6: finishes inspection at 7.18
# Part 6: good part produced at 7.18
# Part 7: starts inspection at 7.18
# Part 5: finishes machining at 7.42
# Part 8: starts machining at 7.42
# Part 7: finishes inspection at 7.96
# Part 7: good part produced at 7.96
# Part 5: starts inspection at 7.96
# Part 8: finishes machining at 8.08
# Part 9: starts machining at 8.08
# Part 5: finishes inspection at 8.75
# Part 5: good part produced at 8.75
# Part 8: starts inspection at 8.75
# Part 9: finishes machining at 8.77
# Machine breaks down at 9.12
# Part 8: finishes inspection at 9.55
# Part 8: good part produced at 9.55
# Part 9: starts inspection at 9.55
# Part 9: finishes inspection at 10.30
# Part 9: good part produced at 10.30
# Part 10: starts machining at 11.02
# Part 10: finishes machining at 11.68
# Part 11: starts machining at 11.68
# Part 10: starts inspection at 11.68
# Part 11: finishes machining at 12.34
# Part 12: starts machining at 12.34
# Part 10: finishes inspection at 12.46
# Part 10: good part produced at 12.46
# Part 11: starts inspection at 12.46
# Part 12: finishes machining at 13.00
# Part 13: starts machining at 13.00
# Part 11: finishes inspection at 13.26
# Part 11: good part produced at 13.26
# Part 12: starts inspection at 13.26
# Part 13: finishes machining at 13.68
# Part 14: starts machining at 13.68
# Part 12: finishes inspection at 14.04
# Part 12: good part produced at 14.04
# Part 13: starts inspection at 14.04
# Part 14: finishes machining at 14.34
# Part 15: starts machining at 14.34
# Part 13: finishes inspection at 14.82
# Part 13: good part produced at 14.82
# Part 14: starts inspection at 14.82
# Part 15: finishes machining at 15.02
# Part 16: starts machining at 15.02
# Part 14: finishes inspection at 15.61
# Part 14: good part produced at 15.61
# Part 15: starts inspection at 15.61
# Part 16: finishes machining at 15.68
# Part 17: starts machining at 15.68
# Part 17: finishes machining at 16.37
# Part 18: starts machining at 16.37
# Part 15: finishes inspection at 16.37
# Part 15: good part produced at 16.37
# Part 16: starts inspection at 16.37
# Part 18: finishes machining at 17.04
# Part 19: starts machining at 17.04
# Part 16: finishes inspection at 17.14
# Part 16: good part produced at 17.14
# Part 17: starts inspection at 17.14
# Part 19: finishes machining at 17.73
# Part 20: starts machining at 17.73
# Part 17: finishes inspection at 17.91
# Part 17: good part produced at 17.91
# Part 18: starts inspection at 17.91
# Part 20: finishes machining at 18.39
# Part 21: starts machining at 18.49
# Part 18: finishes inspection at 18.67
# Part 18: good part produced at 18.67
# Part 19: starts inspection at 18.67
# Part 21: finishes machining at 19.19
# Part 22: starts machining at 19.37
# Part 19: finishes inspection at 19.43
# Part 19: sent back for rework at 19.43
# Part 20: starts inspection at 19.43
# Part 22: finishes machining at 20.04
# Part 19: starts machining at 20.04
# Part 20: finishes inspection at 20.18
# Part 20: good part produced at 20.18
# Part 21: starts inspection at 20.18
# Part 19: finishes machining at 20.70
# Part 21: finishes inspection at 20.97
# Part 21: good part produced at 20.97
# Part 22: starts inspection at 20.97
# Part 22: finishes inspection at 21.73
# Part 22: good part produced at 21.73
# Part 19: starts inspection at 21.73
# Part 19: finishes inspection at 22.53
# Part 19: good part produced at 22.53
# Part 23: starts machining at 25.38
# Part 23: finishes machining at 26.07
# Part 23: starts inspection at 26.07
# Part 24: starts machining at 26.13
# Part 24: finishes machining at 26.81
# Part 25: starts machining at 26.81
# Part 23: finishes inspection at 26.87
# Part 23: good part produced at 26.87
# Part 24: starts inspection at 26.87
# Part 25: finishes machining at 27.49
# Part 26: starts machining at 27.49
# Part 24: finishes inspection at 27.65
# Part 24: good part produced at 27.65
# Part 25: starts inspection at 27.65
# Part 26: finishes machining at 28.16
# Part 27: starts machining at 28.16
# Part 25: finishes inspection at 28.44
# Part 25: good part produced at 28.44
# Part 26: starts inspection at 28.44
# Part 27: finishes machining at 28.84
# Part 28: starts machining at 28.84
# Part 26: finishes inspection at 29.24
# Part 26: good part produced at 29.24
# Part 27: starts inspection at 29.24
# Part 28: finishes machining at 29.52
# Part 29: starts machining at 29.52
# Part 27: finishes inspection at 30.02
# Part 27: good part produced at 30.02
# Part 28: starts inspection at 30.02
# Part 29: finishes machining at 30.20
# Part 30: starts machining at 30.20
# Part 28: finishes inspection at 30.77
# Part 28: sent back for rework at 30.77
# Part 29: starts inspection at 30.77
# Part 30: finishes machining at 30.86
# Part 31: starts machining at 30.86
# Part 31: finishes machining at 31.56
# Part 32: starts machining at 31.56
# Part 29: finishes inspection at 31.57
# Part 29: sent back for rework at 31.57
# Part 30: starts inspection at 31.57
# Part 32: finishes machining at 32.22
# Part 28: starts machining at 32.22
# Part 30: finishes inspection at 32.36
# Part 30: sent back for rework at 32.36
# Part 31: starts inspection at 32.36
# Part 28: finishes machining at 32.92
# Part 33: starts machining at 32.92
# Part 31: finishes inspection at 33.14
# Part 31: good part produced at 33.14
# Part 32: starts inspection at 33.14
# Part 33: finishes machining at 33.57
# Part 29: starts machining at 33.57
# Part 32: finishes inspection at 33.90
# Part 32: good part produced at 33.90
# Part 28: starts inspection at 33.90
# Part 29: finishes machining at 34.25
# Part 30: starts machining at 34.25
# Part 28: finishes inspection at 34.66
# Part 28: good part produced at 34.66
# Part 33: starts inspection at 34.66
# Part 30: finishes machining at 34.94
# Part 34: starts machining at 34.94
# Part 33: finishes inspection at 35.42
# Part 33: good part produced at 35.42
# Part 29: starts inspection at 35.42
# Part 34: finishes machining at 35.62
# Part 35: starts machining at 35.62
# Part 29: finishes inspection at 36.18
# Part 29: good part produced at 36.18
# Part 30: starts inspection at 36.18
# Part 35: finishes machining at 36.32
# Part 36: starts machining at 36.32
# Part 30: finishes inspection at 36.97
# Part 30: good part produced at 36.97
# Part 34: starts inspection at 36.97
# Part 36: finishes machining at 36.99
# Part 37: starts machining at 36.99
# Part 37: finishes machining at 37.65
# Part 38: starts machining at 37.65
# Part 34: finishes inspection at 37.72
# Part 34: good part produced at 37.72
# Part 35: starts inspection at 37.72
# Part 38: finishes machining at 38.31
# Part 39: starts machining at 38.31
# Part 35: finishes inspection at 38.48
# Part 35: good part produced at 38.48
# Part 36: starts inspection at 38.48
# Part 39: finishes machining at 38.99
# Part 40: starts machining at 38.99
# Part 36: finishes inspection at 39.27
# Part 36: good part produced at 39.27
# Part 37: starts inspection at 39.27
# Part 40: finishes machining at 39.68
# Part 41: starts machining at 39.68
# Part 37: finishes inspection at 40.07
# Part 37: good part produced at 40.07
# Part 38: starts inspection at 40.07
# Part 41: finishes machining at 40.35
# Part 42: starts machining at 40.35
# Part 38: finishes inspection at 40.86
# Part 38: good part produced at 40.86
# Part 39: starts inspection at 40.86
# Part 42: finishes machining at 41.01
# Part 43: starts machining at 41.01
# Part 39: finishes inspection at 41.63
# Part 39: good part produced at 41.63
# Part 40: starts inspection at 41.63
# Part 43: finishes machining at 41.69
# Part 44: starts machining at 41.69
# Part 44: finishes machining at 42.36
# Part 45: starts machining at 42.36
# Part 40: finishes inspection at 42.39
# Part 40: good part produced at 42.39
# Part 41: starts inspection at 42.39
# Part 45: finishes machining at 43.05
# Part 46: starts machining at 43.05
# Part 41: finishes inspection at 43.14
# Part 41: good part produced at 43.14
# Part 42: starts inspection at 43.14
# Part 46: finishes machining at 43.72
# Part 47: starts machining at 43.72
# Part 42: finishes inspection at 43.91
# Part 42: good part produced at 43.91
# Part 43: starts inspection at 43.91
# Part 47: finishes machining at 44.40
# Part 48: starts machining at 44.40
# Part 43: finishes inspection at 44.68
# Part 43: good part produced at 44.68
# Part 44: starts inspection at 44.68
# Part 48: finishes machining at 45.05
# Part 49: starts machining at 45.05
# Part 44: finishes inspection at 45.48
# Part 44: good part produced at 45.48
# Part 45: starts inspection at 45.48
# Part 49: finishes machining at 45.75
# Part 50: starts machining at 45.75
# Part 45: finishes inspection at 46.27
# Part 45: good part produced at 46.27
# Part 46: starts inspection at 46.27
# Part 50: finishes machining at 46.40
# Part 51: starts machining at 46.40
# Part 46: finishes inspection at 47.04
# Part 46: good part produced at 47.04
# Part 47: starts inspection at 47.04
# Part 51: finishes machining at 47.06
# Part 52: starts machining at 47.06
# Part 52: finishes machining at 47.73
# Part 53: starts machining at 47.73
# Part 47: finishes inspection at 47.83
# Part 47: good part produced at 47.83
# Part 48: starts inspection at 47.83
# Part 53: finishes machining at 48.40
# Part 48: finishes inspection at 48.63
# Part 48: good part produced at 48.63
# Part 49: starts inspection at 48.63
# Part 49: finishes inspection at 49.41
# Part 49: good part produced at 49.41
# Part 50: starts inspection at 49.41
# Part 50: finishes inspection at 50.18
# Part 50: good part produced at 50.18
# Part 51: starts inspection at 50.18
# Part 51: finishes inspection at 50.96
# Part 51: good part produced at 50.96
# Part 52: starts inspection at 50.96
# Part 54: starts machining at 51.17
# Part 52: finishes inspection at 51.75
# Part 52: good part produced at 51.75
# Part 53: starts inspection at 51.75
# Part 54: finishes machining at 51.85
# Part 55: starts machining at 51.85
# Part 53: finishes inspection at 52.50
# Part 53: good part produced at 52.50
# Part 54: starts inspection at 52.50
# Part 55: finishes machining at 52.55
# Part 56: starts machining at 52.55
# Part 56: finishes machining at 53.20
# Part 57: starts machining at 53.20
# Part 54: finishes inspection at 53.26
# Part 54: good part produced at 53.26
# Part 55: starts inspection at 53.26
# Part 57: finishes machining at 53.87
# Part 58: starts machining at 53.87
# Part 55: finishes inspection at 54.05
# Part 55: good part produced at 54.05
# Part 56: starts inspection at 54.05
# Part 58: finishes machining at 54.54
# Part 59: starts machining at 54.54
# Part 56: finishes inspection at 54.82
# Part 56: good part produced at 54.82
# Part 57: starts inspection at 54.82
# Part 59: finishes machining at 55.23
# Part 60: starts machining at 55.33
# Part 57: finishes inspection at 55.61
# Part 57: good part produced at 55.61
# Part 58: starts inspection at 55.61
# Part 60: finishes machining at 56.00
# Part 61: starts machining at 56.00
# Part 58: finishes inspection at 56.37
# Part 58: sent back for rework at 56.37
# Part 59: starts inspection at 56.37
# Part 61: finishes machining at 56.69
# Part 58: starts machining at 56.69
# Part 59: finishes inspection at 57.15
# Part 59: sent back for rework at 57.15
# Part 60: starts inspection at 57.15
# Part 58: finishes machining at 57.39
# Part 62: starts machining at 57.39
# Part 60: finishes inspection at 57.91
# Part 60: good part produced at 57.91
# Part 61: starts inspection at 57.91
# Part 62: finishes machining at 58.05
# Part 59: starts machining at 58.05
# Part 61: finishes inspection at 58.70
# Part 61: good part produced at 58.70
# Part 58: starts inspection at 58.70
# Part 59: finishes machining at 58.74
# Part 58: finishes inspection at 59.46
# Part 58: good part produced at 59.46
# Part 62: starts inspection at 59.46
# Hour 1: 60 parts produced.
# Part 62: finishes inspection at 60.25
# Part 62: good part produced at 60.25
# Part 59: starts inspection at 60.25
# Part 59: finishes inspection at 61.03
# Part 59: good part produced at 61.03
# Part 63: starts machining at 62.26
# Part 63: finishes machining at 62.95
# Part 63: starts inspection at 62.95
# Part 63: finishes inspection at 63.70
# Part 63: good part produced at 63.70
# Part 64: starts machining at 66.62
# Part 64: finishes machining at 67.31
# Part 65: starts machining at 67.31
# Part 64: starts inspection at 67.31
# Part 65: finishes machining at 67.96
# Part 64: finishes inspection at 68.06
# Part 64: good part produced at 68.06
# Part 65: starts inspection at 68.06
# Part 65: finishes inspection at 68.84
# Part 65: good part produced at 68.84
# Part 66: starts machining at 69.78
# Part 66: finishes machining at 70.46
# Part 66: starts inspection at 70.46
# Part 67: starts machining at 70.70
# Part 66: finishes inspection at 71.22
# Part 66: good part produced at 71.22
# Part 67: finishes machining at 71.37
# Part 67: starts inspection at 71.37
# Part 68: starts machining at 71.71
# Part 67: finishes inspection at 72.16
# Part 67: good part produced at 72.16
# Part 68: finishes machining at 72.36
# Part 68: starts inspection at 72.36
# Part 68: finishes inspection at 73.13
# Part 68: sent back for rework at 73.13
# Part 68: starts machining at 73.13
# Part 68: finishes machining at 73.82
# Part 69: starts machining at 73.82
# Part 68: starts inspection at 73.82
# Part 69: finishes machining at 74.48
# Part 70: starts machining at 74.59
# Part 68: finishes inspection at 74.60
# Part 68: good part produced at 74.60
# Part 69: starts inspection at 74.60
# Part 70: finishes machining at 75.27
# Part 69: finishes inspection at 75.35
# Part 69: sent back for rework at 75.35
# Part 70: starts inspection at 75.35
# Part 69: starts machining at 75.35
# Part 69: finishes machining at 76.05
# Part 71: starts machining at 76.05
# Part 70: finishes inspection at 76.15
# Part 70: good part produced at 76.15
# Part 69: starts inspection at 76.15
# Part 71: finishes machining at 76.74
# Part 72: starts machining at 76.74
# Part 69: finishes inspection at 76.91
# Part 69: good part produced at 76.91
# Part 71: starts inspection at 76.91
# Part 72: finishes machining at 77.43
# Part 73: starts machining at 77.43
# Part 71: finishes inspection at 77.70
# Part 71: good part produced at 77.70
# Part 72: starts inspection at 77.70
# Part 73: finishes machining at 78.13
# Part 74: starts machining at 78.13
# Part 72: finishes inspection at 78.46
# Part 72: good part produced at 78.46
# Part 73: starts inspection at 78.46
# Part 74: finishes machining at 78.78
# Part 75: starts machining at 78.98
# Part 73: finishes inspection at 79.26
# Part 73: good part produced at 79.26
# Part 74: starts inspection at 79.26
# Part 75: finishes machining at 79.66
# Part 76: starts machining at 79.66
# Part 74: finishes inspection at 80.05
# Part 74: good part produced at 80.05
# Part 75: starts inspection at 80.05
# Part 76: finishes machining at 80.36
# Part 75: finishes inspection at 80.85
# Part 75: sent back for rework at 80.85
# Part 76: starts inspection at 80.85
# Part 75: starts machining at 80.85
# Part 75: finishes machining at 81.51
# Part 77: starts machining at 81.51
# Part 76: finishes inspection at 81.63
# Part 76: good part produced at 81.63
# Part 75: starts inspection at 81.63
# Part 77: finishes machining at 82.20
# Part 75: finishes inspection at 82.42
# Part 75: good part produced at 82.42
# Part 77: starts inspection at 82.42
# Part 77: finishes inspection at 83.19
# Part 77: good part produced at 83.19
# Part 78: starts machining at 84.17
# Part 78: finishes machining at 84.87
# Part 79: starts machining at 84.87
# Part 78: starts inspection at 84.87
# Part 79: finishes machining at 85.53
# Part 78: finishes inspection at 85.66
# Part 78: good part produced at 85.66
# Part 79: starts inspection at 85.66
# Part 80: starts machining at 86.25
# Part 79: finishes inspection at 86.42
# Part 79: sent back for rework at 86.42
# Part 80: finishes machining at 86.91
# Part 79: starts machining at 86.91
# Part 80: starts inspection at 86.91
# Part 79: finishes machining at 87.57
# Part 80: finishes inspection at 87.67
# Part 80: good part produced at 87.67
# Part 79: starts inspection at 87.67
# Part 81: starts machining at 87.83
# Part 79: finishes inspection at 88.47
# Part 79: good part produced at 88.47
# Part 81: finishes machining at 88.51
# Part 82: starts machining at 88.51
# Part 81: starts inspection at 88.51
# Part 82: finishes machining at 89.21
# Part 83: starts machining at 89.21
# Part 81: finishes inspection at 89.29
# Part 81: good part produced at 89.29
# Part 82: starts inspection at 89.29
# Part 83: finishes machining at 89.87
# Part 82: finishes inspection at 90.05
# Part 82: good part produced at 90.05
# Part 83: starts inspection at 90.05
# Part 83: finishes inspection at 90.81
# Part 83: good part produced at 90.81
# Part 84: starts machining at 91.47
# Part 84: finishes machining at 92.16
# Part 85: starts machining at 92.16
# Part 84: starts inspection at 92.16
# Part 85: finishes machining at 92.84
# Part 86: starts machining at 92.84
# Part 84: finishes inspection at 92.93
# Part 84: good part produced at 92.93
# Part 85: starts inspection at 92.93
# Part 86: finishes machining at 93.52
# Part 87: starts machining at 93.52
# Part 85: finishes inspection at 93.68
# Part 85: good part produced at 93.68
# Part 86: starts inspection at 93.68
# Part 87: finishes machining at 94.19
# Part 88: starts machining at 94.19
# Part 86: finishes inspection at 94.47
# Part 86: good part produced at 94.47
# Part 87: starts inspection at 94.47
# Part 88: finishes machining at 94.88
# Part 87: finishes inspection at 95.22
# Part 87: good part produced at 95.22
# Part 88: starts inspection at 95.22
# Part 89: starts machining at 95.80
# Part 88: finishes inspection at 95.99
# Part 88: good part produced at 95.99
# Part 89: finishes machining at 96.49
# Part 90: starts machining at 96.49
# Part 89: starts inspection at 96.49
# Part 90: finishes machining at 97.15
# Part 91: starts machining at 97.15
# Part 89: finishes inspection at 97.26
# Part 89: good part produced at 97.26
# Part 90: starts inspection at 97.26
# Part 91: finishes machining at 97.81
# Part 92: starts machining at 97.81
# Part 90: finishes inspection at 98.05
# Part 90: good part produced at 98.05
# Part 91: starts inspection at 98.05
# Part 92: finishes machining at 98.50
# Part 93: starts machining at 98.50
# Part 91: finishes inspection at 98.82
# Part 91: good part produced at 98.82
# Part 92: starts inspection at 98.82
# Part 93: finishes machining at 99.18
# Part 94: starts machining at 99.18
# Part 92: finishes inspection at 99.60
# Part 92: good part produced at 99.60
# Part 93: starts inspection at 99.60
# Part 94: finishes machining at 99.86
# Part 95: starts machining at 99.86
# Part 93: finishes inspection at 100.36
# Part 93: good part produced at 100.36
# Part 94: starts inspection at 100.36
# Part 95: finishes machining at 100.53
# Part 96: starts machining at 100.53
# Part 94: finishes inspection at 101.12
# Part 94: good part produced at 101.12
# Part 95: starts inspection at 101.12
# Part 96: finishes machining at 101.18
# Part 97: starts machining at 101.18
# Part 97: finishes machining at 101.85
# Part 95: finishes inspection at 101.90
# Part 95: good part produced at 101.90
# Part 96: starts inspection at 101.90
# Part 98: starts machining at 102.24
# Part 96: finishes inspection at 102.69
# Part 96: good part produced at 102.69
# Part 97: starts inspection at 102.69
# Part 98: finishes machining at 102.90
# Part 99: starts machining at 103.36
# Part 97: finishes inspection at 103.44
# Part 97: good part produced at 103.44
# Part 98: starts inspection at 103.44
# Part 99: finishes machining at 104.03
# Part 100: starts machining at 104.03
# Part 98: finishes inspection at 104.19
# Part 98: good part produced at 104.19
# Part 99: starts inspection at 104.19
# Part 100: finishes machining at 104.71
# Part 101: starts machining at 104.71
# Part 99: finishes inspection at 104.97
# Part 99: good part produced at 104.97
# Part 100: starts inspection at 104.97
# Part 101: finishes machining at 105.36
# Part 102: starts machining at 105.36
# Part 100: finishes inspection at 105.76
# Part 100: good part produced at 105.76
# Part 101: starts inspection at 105.76
# Part 102: finishes machining at 106.02
# Part 103: starts machining at 106.02
# Part 101: finishes inspection at 106.55
# Part 101: good part produced at 106.55
# Part 102: starts inspection at 106.55
# Part 103: finishes machining at 106.70
# Part 104: starts machining at 106.70
# Part 102: finishes inspection at 107.33
# Part 102: good part produced at 107.33
# Part 103: starts inspection at 107.33
# Part 104: finishes machining at 107.38
# Part 105: starts machining at 107.38
# Part 105: finishes machining at 108.08
# Part 106: starts machining at 108.08
# Part 103: finishes inspection at 108.11
# Part 103: good part produced at 108.11
# Part 104: starts inspection at 108.11
# Part 106: finishes machining at 108.77
# Part 107: starts machining at 108.77
# Part 104: finishes inspection at 108.89
# Part 104: good part produced at 108.89
# Part 105: starts inspection at 108.89
# Part 107: finishes machining at 109.46
# Part 108: starts machining at 109.46
# Part 105: finishes inspection at 109.69
# Part 105: good part produced at 109.69
# Part 106: starts inspection at 109.69
# Part 108: finishes machining at 110.14
# Part 109: starts machining at 110.14
# Part 106: finishes inspection at 110.45
# Part 106: good part produced at 110.45
# Part 107: starts inspection at 110.45
# Part 109: finishes machining at 110.82
# Part 110: starts machining at 110.82
# Part 107: finishes inspection at 111.23
# Part 107: sent back for rework at 111.23
# Part 108: starts inspection at 111.23
# Part 110: finishes machining at 111.48
# Part 107: starts machining at 111.48
# Part 108: finishes inspection at 111.99
# Part 108: good part produced at 111.99
# Part 109: starts inspection at 111.99
# Part 107: finishes machining at 112.15
# Part 111: starts machining at 112.15
# Part 109: finishes inspection at 112.75
# Part 109: good part produced at 112.75
# Part 110: starts inspection at 112.75
# Part 111: finishes machining at 112.81
# Part 112: starts machining at 112.81
# Part 112: finishes machining at 113.48
# Part 113: starts machining at 113.48
# Part 110: finishes inspection at 113.50
# Part 110: good part produced at 113.50
# Part 107: starts inspection at 113.50
# Part 113: finishes machining at 114.15
# Part 114: starts machining at 114.15
# Part 107: finishes inspection at 114.28
# Part 107: good part produced at 114.28
# Part 111: starts inspection at 114.28
# Part 114: finishes machining at 114.83
# Part 111: finishes inspection at 115.06
# Part 111: good part produced at 115.06
# Part 112: starts inspection at 115.06
# Part 112: finishes inspection at 115.85
# Part 112: good part produced at 115.85
# Part 113: starts inspection at 115.85
# Part 115: starts machining at 116.47
# Part 113: finishes inspection at 116.60
# Part 113: good part produced at 116.60
# Part 114: starts inspection at 116.60
# Part 115: finishes machining at 117.15
# Part 116: starts machining at 117.15
# Part 114: finishes inspection at 117.40
# Part 114: good part produced at 117.40
# Part 115: starts inspection at 117.40
# Part 116: finishes machining at 117.84
# Part 117: starts machining at 117.84
# Part 115: finishes inspection at 118.18
# Part 115: good part produced at 118.18
# Part 116: starts inspection at 118.18
# Part 117: finishes machining at 118.51
# Part 118: starts machining at 118.51
# Part 116: finishes inspection at 118.95
# Part 116: sent back for rework at 118.95
# Part 117: starts inspection at 118.95
# Part 118: finishes machining at 119.19
# Part 119: starts machining at 119.19
# Part 117: finishes inspection at 119.72
# Part 117: good part produced at 119.72
# Part 118: starts inspection at 119.72
# Part 119: finishes machining at 119.86
# Part 120: starts machining at 119.86
# Hour 2: 56 parts produced.
# Part 118: finishes inspection at 120.49
# Part 118: good part produced at 120.49
# Part 119: starts inspection at 120.49
# Part 120: finishes machining at 120.52
# Part 121: starts machining at 120.52
# Part 121: finishes machining at 121.18
# Part 122: starts machining at 121.18
# Part 119: finishes inspection at 121.25
# Part 119: good part produced at 121.25
# Part 120: starts inspection at 121.25
# Part 122: finishes machining at 121.85
# Part 123: starts machining at 121.85
# Part 120: finishes inspection at 122.04
# Part 120: sent back for rework at 122.04
# Part 121: starts inspection at 122.04
# Part 123: finishes machining at 122.51
# Part 116: starts machining at 122.51
# Part 121: finishes inspection at 122.79
# Part 121: good part produced at 122.79
# Part 122: starts inspection at 122.79
# Part 116: finishes machining at 123.21
# Part 124: starts machining at 123.21
# Part 122: finishes inspection at 123.58
# Part 122: good part produced at 123.58
# Part 123: starts inspection at 123.58
# Part 124: finishes machining at 123.90
# Part 125: starts machining at 123.90
# Part 123: finishes inspection at 124.37
# Part 123: sent back for rework at 124.37
# Part 116: starts inspection at 124.37
# Part 125: finishes machining at 124.56
# Part 126: starts machining at 124.56
# Part 116: finishes inspection at 125.13
# Part 116: good part produced at 125.13
# Part 124: starts inspection at 125.13
# Part 126: finishes machining at 125.24
# Part 120: starts machining at 125.24
# Part 124: finishes inspection at 125.89
# Part 124: good part produced at 125.89
# Part 125: starts inspection at 125.89
# Part 120: finishes machining at 125.93
# Part 127: starts machining at 125.93
# Part 127: finishes machining at 126.61
# Part 128: starts machining at 126.61
# Part 125: finishes inspection at 126.67
# Part 125: good part produced at 126.67
# Part 126: starts inspection at 126.67
# Part 128: finishes machining at 127.27
# Part 123: starts machining at 127.27
# Part 126: finishes inspection at 127.47
# Part 126: good part produced at 127.47
# Part 120: starts inspection at 127.47
# Part 123: finishes machining at 127.95
# Part 129: starts machining at 127.95
# Part 120: finishes inspection at 128.26
# Part 120: good part produced at 128.26
# Part 127: starts inspection at 128.26
# Part 129: finishes machining at 128.61
# Part 130: starts machining at 128.61
# Part 127: finishes inspection at 129.04
# Part 127: good part produced at 129.04
# Part 128: starts inspection at 129.04
# Part 130: finishes machining at 129.29
# Part 131: starts machining at 129.29
# Part 128: finishes inspection at 129.83
# Part 128: good part produced at 129.83
# Part 123: starts inspection at 129.83
# Part 131: finishes machining at 129.98
# Part 132: starts machining at 129.98
# Part 123: finishes inspection at 130.59
# Part 123: good part produced at 130.59
# Part 129: starts inspection at 130.59
# Part 132: finishes machining at 130.68
# Part 133: starts machining at 130.68
# Part 133: finishes machining at 131.35
# Part 134: starts machining at 131.35
# Part 129: finishes inspection at 131.35
# Part 129: good part produced at 131.35
# Part 130: starts inspection at 131.35
# Part 134: finishes machining at 132.02
# Part 135: starts machining at 132.02
# Part 130: finishes inspection at 132.12
# Part 130: good part produced at 132.12
# Part 131: starts inspection at 132.12
# Part 135: finishes machining at 132.71
# Part 136: starts machining at 132.71
# Part 131: finishes inspection at 132.92
# Part 131: good part produced at 132.92
# Part 132: starts inspection at 132.92
# Part 136: finishes machining at 133.39
# Part 137: starts machining at 133.39
# Part 132: finishes inspection at 133.70
# Part 132: good part produced at 133.70
# Part 133: starts inspection at 133.70
# Part 137: finishes machining at 134.07
# Part 138: starts machining at 134.07
# Part 133: finishes inspection at 134.50
# Part 133: good part produced at 134.50
# Part 134: starts inspection at 134.50
# Part 138: finishes machining at 134.76
# Part 139: starts machining at 134.76
# Part 134: finishes inspection at 135.27
# Part 134: good part produced at 135.27
# Part 135: starts inspection at 135.27
# Part 139: finishes machining at 135.44
# Part 140: starts machining at 135.44
# Part 135: finishes inspection at 136.03
# Part 135: good part produced at 136.03
# Part 136: starts inspection at 136.03
# Part 140: finishes machining at 136.14
# Part 141: starts machining at 136.14
# Part 136: finishes inspection at 136.80
# Part 136: good part produced at 136.80
# Part 137: starts inspection at 136.80
# Part 141: finishes machining at 136.82
# Part 142: starts machining at 137.13
# Part 137: finishes inspection at 137.55
# Part 137: good part produced at 137.55
# Part 138: starts inspection at 137.55
# Part 142: finishes machining at 137.78
# Part 138: finishes inspection at 138.34
# Part 138: good part produced at 138.34
# Part 139: starts inspection at 138.34
# Part 143: starts machining at 139.03
# Part 139: finishes inspection at 139.14
# Part 139: sent back for rework at 139.14
# Part 140: starts inspection at 139.14
# Part 143: finishes machining at 139.69
# Part 139: starts machining at 139.69
# Part 140: finishes inspection at 139.93
# Part 140: good part produced at 139.93
# Part 141: starts inspection at 139.93
# Part 139: finishes machining at 140.35
# Part 144: starts machining at 140.35
# Part 141: finishes inspection at 140.71
# Part 141: good part produced at 140.71
# Part 142: starts inspection at 140.71
# Part 144: finishes machining at 141.03
# Part 142: finishes inspection at 141.48
# Part 142: good part produced at 141.48
# Part 143: starts inspection at 141.48
# Part 145: starts machining at 141.66
# Part 143: finishes inspection at 142.24
# Part 143: good part produced at 142.24
# Part 139: starts inspection at 142.24
# Part 145: finishes machining at 142.34
# Part 146: starts machining at 142.34
# Part 139: finishes inspection at 143.01
# Part 139: good part produced at 143.01
# Part 144: starts inspection at 143.01
# Part 146: finishes machining at 143.01
# Part 147: starts machining at 143.01
# Part 147: finishes machining at 143.68
# Part 148: starts machining at 143.68
# Part 144: finishes inspection at 143.80
# Part 144: good part produced at 143.80
# Part 145: starts inspection at 143.80
# Part 148: finishes machining at 144.34
# Part 149: starts machining at 144.34
# Part 145: finishes inspection at 144.55
# Part 145: good part produced at 144.55
# Part 146: starts inspection at 144.55
# Part 149: finishes machining at 145.00
# Part 150: starts machining at 145.00
# Part 146: finishes inspection at 145.31
# Part 146: good part produced at 145.31
# Part 147: starts inspection at 145.31
# Part 150: finishes machining at 145.66
# Part 151: starts machining at 145.66
# Part 147: finishes inspection at 146.11
# Part 147: good part produced at 146.11
# Part 148: starts inspection at 146.11
# Part 151: finishes machining at 146.34
# Part 152: starts machining at 146.34
# Part 148: finishes inspection at 146.87
# Part 148: good part produced at 146.87
# Part 149: starts inspection at 146.87
# Part 152: finishes machining at 146.99
# Part 153: starts machining at 146.99
# Part 149: finishes inspection at 147.67
# Part 149: good part produced at 147.67
# Part 150: starts inspection at 147.67
# Part 153: finishes machining at 147.67
# Part 154: starts machining at 147.67
# Part 154: finishes machining at 148.35
# Part 155: starts machining at 148.35
# Part 150: finishes inspection at 148.46
# Part 150: good part produced at 148.46
# Part 151: starts inspection at 148.46
# Part 155: finishes machining at 149.04
# Part 156: starts machining at 149.04
# Part 151: finishes inspection at 149.24
# Part 151: sent back for rework at 149.24
# Part 152: starts inspection at 149.24
# Part 156: finishes machining at 149.70
# Part 157: starts machining at 149.70
# Part 152: finishes inspection at 150.03
# Part 152: sent back for rework at 150.03
# Part 153: starts inspection at 150.03
# Part 157: finishes machining at 150.39
# Part 151: starts machining at 150.39
# Part 153: finishes inspection at 150.81
# Part 153: good part produced at 150.81
# Part 154: starts inspection at 150.81
# Part 151: finishes machining at 151.04
# Part 158: starts machining at 151.04
# Part 154: finishes inspection at 151.61
# Part 154: good part produced at 151.61
# Part 155: starts inspection at 151.61
# Part 158: finishes machining at 151.70
# Part 159: starts machining at 151.70
# Part 159: finishes machining at 152.36
# Part 152: starts machining at 152.36
# Part 155: finishes inspection at 152.40
# Part 155: good part produced at 152.40
# Part 156: starts inspection at 152.40
# Part 152: finishes machining at 153.04
# Part 160: starts machining at 153.04
# Part 156: finishes inspection at 153.18
# Part 156: good part produced at 153.18
# Part 157: starts inspection at 153.18
# Part 160: finishes machining at 153.74
# Part 161: starts machining at 153.74
# Part 157: finishes inspection at 153.96
# Part 157: good part produced at 153.96
# Part 151: starts inspection at 153.96
# Part 161: finishes machining at 154.42
# Part 162: starts machining at 154.42
# Part 151: finishes inspection at 154.75
# Part 151: good part produced at 154.75
# Part 158: starts inspection at 154.75
# Part 162: finishes machining at 155.08
# Part 163: starts machining at 155.08
# Part 158: finishes inspection at 155.51
# Part 158: good part produced at 155.51
# Part 159: starts inspection at 155.51
# Part 163: finishes machining at 155.73
# Part 164: starts machining at 155.73
# Part 159: finishes inspection at 156.27
# Part 159: good part produced at 156.27
# Part 152: starts inspection at 156.27
# Part 164: finishes machining at 156.38
# Part 165: starts machining at 156.38
# Part 152: finishes inspection at 157.03
# Part 152: good part produced at 157.03
# Part 160: starts inspection at 157.03
# Part 165: finishes machining at 157.05
# Part 166: starts machining at 157.05
# Part 166: finishes machining at 157.72
# Part 167: starts machining at 157.77
# Part 160: finishes inspection at 157.82
# Part 160: good part produced at 157.82
# Part 161: starts inspection at 157.82
# Part 167: finishes machining at 158.47
# Part 161: finishes inspection at 158.60
# Part 161: good part produced at 158.60
# Part 162: starts inspection at 158.60
# Part 168: starts machining at 158.94
# Part 162: finishes inspection at 159.40
# Part 162: good part produced at 159.40
# Part 163: starts inspection at 159.40
# Part 168: finishes machining at 159.61
# Part 169: starts machining at 159.61
# Part 163: finishes inspection at 160.19
# Part 163: good part produced at 160.19
# Part 164: starts inspection at 160.19
# Part 169: finishes machining at 160.27
# Part 164: finishes inspection at 160.96
# Part 164: good part produced at 160.96
# Part 165: starts inspection at 160.96
# Part 170: starts machining at 161.24
# Part 165: finishes inspection at 161.74
# Part 165: good part produced at 161.74
# Part 166: starts inspection at 161.74
# Part 170: finishes machining at 161.90
# Part 171: starts machining at 161.90
# Part 166: finishes inspection at 162.53
# Part 166: good part produced at 162.53
# Part 167: starts inspection at 162.53
# Part 171: finishes machining at 162.57
# Part 172: starts machining at 162.75
# Part 167: finishes inspection at 163.29
# Part 167: sent back for rework at 163.29
# Part 168: starts inspection at 163.29
# Part 172: finishes machining at 163.42
# Part 173: starts machining at 163.42
# Part 168: finishes inspection at 164.08
# Part 168: good part produced at 164.08
# Part 169: starts inspection at 164.08
# Part 173: finishes machining at 164.11
# Part 174: starts machining at 164.11
# Part 174: finishes machining at 164.80
# Part 167: starts machining at 164.80
# Part 169: finishes inspection at 164.88
# Part 169: good part produced at 164.88
# Part 170: starts inspection at 164.88
# Part 167: finishes machining at 165.47
# Part 175: starts machining at 165.47
# Part 170: finishes inspection at 165.68
# Part 170: good part produced at 165.68
# Part 171: starts inspection at 165.68
# Part 175: finishes machining at 166.13
# Part 176: starts machining at 166.13
# Part 171: finishes inspection at 166.46
# Part 171: good part produced at 166.46
# Part 172: starts inspection at 166.46
# Part 176: finishes machining at 166.78
# Part 177: starts machining at 166.78
# Part 172: finishes inspection at 167.23
# Part 172: good part produced at 167.23
# Part 173: starts inspection at 167.23
# Part 177: finishes machining at 167.48
# Part 178: starts machining at 167.48
# Part 173: finishes inspection at 168.01
# Part 173: good part produced at 168.01
# Part 174: starts inspection at 168.01
# Part 178: finishes machining at 168.14
# Part 179: starts machining at 168.14
# Part 174: finishes inspection at 168.79
# Part 174: good part produced at 168.79
# Part 167: starts inspection at 168.79
# Part 179: finishes machining at 168.81
# Part 180: starts machining at 168.81
# Part 180: finishes machining at 169.51
# Part 181: starts machining at 169.51
# Part 167: finishes inspection at 169.56
# Part 167: good part produced at 169.56
# Part 175: starts inspection at 169.56
# Part 181: finishes machining at 170.18
# Part 175: finishes inspection at 170.33
# Part 175: good part produced at 170.33
# Part 176: starts inspection at 170.33
# Part 182: starts machining at 170.78
# Part 176: finishes inspection at 171.12
# Part 176: good part produced at 171.12
# Part 177: starts inspection at 171.12
# Part 182: finishes machining at 171.45
# Part 183: starts machining at 171.56
# Part 177: finishes inspection at 171.88
# Part 177: good part produced at 171.88
# Part 178: starts inspection at 171.88
# Part 183: finishes machining at 172.24
# Part 178: finishes inspection at 172.64
# Part 178: good part produced at 172.64
# Part 179: starts inspection at 172.64
# Part 184: starts machining at 172.98
# Part 179: finishes inspection at 173.44
# Part 179: good part produced at 173.44
# Part 180: starts inspection at 173.44
# Part 184: finishes machining at 173.66
# Part 185: starts machining at 173.66
# Part 180: finishes inspection at 174.24
# Part 180: good part produced at 174.24
# Part 181: starts inspection at 174.24
# Part 185: finishes machining at 174.32
# Part 186: starts machining at 174.49
# Part 181: finishes inspection at 175.02
# Part 181: good part produced at 175.02
# Part 182: starts inspection at 175.02
# Part 186: finishes machining at 175.15
# Part 187: starts machining at 175.29
# Part 182: finishes inspection at 175.81
# Part 182: good part produced at 175.81
# Part 183: starts inspection at 175.81
# Part 187: finishes machining at 175.95
# Part 188: starts machining at 175.95
# Part 183: finishes inspection at 176.59
# Part 183: good part produced at 176.59
# Part 184: starts inspection at 176.59
# Part 188: finishes machining at 176.63
# Part 189: starts machining at 177.17
# Part 184: finishes inspection at 177.38
# Part 184: good part produced at 177.38
# Part 185: starts inspection at 177.38
# Part 189: finishes machining at 177.84
# Part 185: finishes inspection at 178.15
# Part 185: good part produced at 178.15
# Part 186: starts inspection at 178.15
# Part 186: finishes inspection at 178.92
# Part 186: good part produced at 178.92
# Part 187: starts inspection at 178.92
# Part 187: finishes inspection at 179.72
# Part 187: good part produced at 179.72
# Part 188: starts inspection at 179.72
# Hour 3: 71 parts produced.
# Part 188: finishes inspection at 180.51
# Part 188: good part produced at 180.51
# Part 189: starts inspection at 180.51
# Part 190: starts machining at 181.10
# Part 189: finishes inspection at 181.30
# Part 189: good part produced at 181.30
# Part 190: finishes machining at 181.79
# Part 190: starts inspection at 181.79
# Part 191: starts machining at 181.81
# Part 191: finishes machining at 182.51
# Part 190: finishes inspection at 182.55
# Part 190: good part produced at 182.55
# Part 191: starts inspection at 182.55
# Part 192: starts machining at 182.69
# Part 191: finishes inspection at 183.31
# Part 191: good part produced at 183.31
# Part 192: finishes machining at 183.36
# Part 192: starts inspection at 183.36
# Part 193: starts machining at 183.46
# Part 193: finishes machining at 184.13
# Part 194: starts machining at 184.13
# Part 192: finishes inspection at 184.14
# Part 192: good part produced at 184.14
# Part 193: starts inspection at 184.14
# Part 194: finishes machining at 184.82
# Part 195: starts machining at 184.82
# Part 193: finishes inspection at 184.90
# Part 193: good part produced at 184.90
# Part 194: starts inspection at 184.90
# Part 195: finishes machining at 185.47
# Part 194: finishes inspection at 185.68
# Part 194: good part produced at 185.68
# Part 195: starts inspection at 185.68
# Part 196: starts machining at 185.78
# Part 195: finishes inspection at 186.45
# Part 195: good part produced at 186.45
# Part 196: finishes machining at 186.47
# Part 196: starts inspection at 186.47
# Part 197: starts machining at 186.86
# Part 196: finishes inspection at 187.24
# Part 196: good part produced at 187.24
# Part 197: finishes machining at 187.54
# Part 198: starts machining at 187.54
# Part 197: starts inspection at 187.54
# Part 198: finishes machining at 188.23
# Part 199: starts machining at 188.23
# Part 197: finishes inspection at 188.31
# Part 197: good part produced at 188.31
# Part 198: starts inspection at 188.31
# Part 199: finishes machining at 188.91
# Part 200: starts machining at 188.91
# Part 198: finishes inspection at 189.08
# Part 198: good part produced at 189.08
# Part 199: starts inspection at 189.08
# Part 200: finishes machining at 189.56
# Part 201: starts machining at 189.60
# Part 199: finishes inspection at 189.88
# Part 199: good part produced at 189.88
# Part 200: starts inspection at 189.88
# Part 201: finishes machining at 190.29
# Part 202: starts machining at 190.29
# Part 200: finishes inspection at 190.67
# Part 200: good part produced at 190.67
# Part 201: starts inspection at 190.67
# Part 202: finishes machining at 190.98
# Part 201: finishes inspection at 191.44
# Part 201: good part produced at 191.44
# Part 202: starts inspection at 191.44
# Part 203: starts machining at 191.93
# Part 202: finishes inspection at 192.23
# Part 202: sent back for rework at 192.23
# Part 203: finishes machining at 192.58
# Part 202: starts machining at 192.58
# Part 203: starts inspection at 192.58
# Part 202: finishes machining at 193.26
# Part 203: finishes inspection at 193.38
# Part 203: good part produced at 193.38
# Part 202: starts inspection at 193.38
# Part 204: starts machining at 193.99
# Part 202: finishes inspection at 194.17
# Part 202: good part produced at 194.17
# Part 204: finishes machining at 194.64
# Part 205: starts machining at 194.64
# Part 204: starts inspection at 194.64
# Part 205: finishes machining at 195.34
# Part 204: finishes inspection at 195.42
# Part 204: good part produced at 195.42
# Part 205: starts inspection at 195.42
# Part 206: starts machining at 195.56
# Part 205: finishes inspection at 196.21
# Part 205: good part produced at 196.21
# Part 206: finishes machining at 196.25
# Part 207: starts machining at 196.25
# Part 206: starts inspection at 196.25
# Part 207: finishes machining at 196.93
# Part 208: starts machining at 196.93
# Part 206: finishes inspection at 197.03
# Part 206: sent back for rework at 197.03
# Part 207: starts inspection at 197.03
# Part 208: finishes machining at 197.59
# Part 209: starts machining at 197.59
# Part 207: finishes inspection at 197.82
# Part 207: good part produced at 197.82
# Part 208: starts inspection at 197.82
# Part 209: finishes machining at 198.27
# Part 206: starts machining at 198.27
# Part 208: finishes inspection at 198.62
# Part 208: good part produced at 198.62
# Part 209: starts inspection at 198.62
# Part 206: finishes machining at 198.93
# Part 210: starts machining at 198.93
# Part 209: finishes inspection at 199.37
# Part 209: good part produced at 199.37
# Part 206: starts inspection at 199.37
# Part 210: finishes machining at 199.63
# Part 211: starts machining at 199.63
# Part 206: finishes inspection at 200.13
# Part 206: good part produced at 200.13
# Part 210: starts inspection at 200.13
# Part 211: finishes machining at 200.30
# Part 212: starts machining at 200.30
# Part 210: finishes inspection at 200.90
# Part 210: good part produced at 200.90
# Part 211: starts inspection at 200.90
# Part 212: finishes machining at 200.98
# Part 213: starts machining at 200.98
# Part 211: finishes inspection at 201.66
# Part 211: good part produced at 201.66
# Part 212: starts inspection at 201.66
# Part 213: finishes machining at 201.67
# Part 214: starts machining at 201.67
# Part 214: finishes machining at 202.35
# Part 215: starts machining at 202.35
# Part 212: finishes inspection at 202.42
# Part 212: good part produced at 202.42
# Part 213: starts inspection at 202.42
# Part 215: finishes machining at 203.05
# Part 216: starts machining at 203.05
# Part 213: finishes inspection at 203.22
# Part 213: good part produced at 203.22
# Part 214: starts inspection at 203.22
# Part 216: finishes machining at 203.71
# Part 217: starts machining at 203.71
# Part 214: finishes inspection at 204.00
# Part 214: sent back for rework at 204.00
# Part 215: starts inspection at 204.00
# Part 217: finishes machining at 204.40
# Part 214: starts machining at 204.40
# Part 215: finishes inspection at 204.78
# Part 215: good part produced at 204.78
# Part 216: starts inspection at 204.78
# Part 214: finishes machining at 205.09
# Part 218: starts machining at 205.09
# Part 216: finishes inspection at 205.56
# Part 216: good part produced at 205.56
# Part 217: starts inspection at 205.56
# Part 218: finishes machining at 205.78
# Part 219: starts machining at 205.78
# Part 217: finishes inspection at 206.35
# Part 217: good part produced at 206.35
# Part 214: starts inspection at 206.35
# Part 219: finishes machining at 206.46
# Part 220: starts machining at 206.46
# Part 214: finishes inspection at 207.13
# Part 214: good part produced at 207.13
# Part 218: starts inspection at 207.13
# Part 220: finishes machining at 207.15
# Part 221: starts machining at 207.15
# Part 221: finishes machining at 207.83
# Part 222: starts machining at 207.83
# Part 218: finishes inspection at 207.90
# Part 218: sent back for rework at 207.90
# Part 219: starts inspection at 207.90
# Part 222: finishes machining at 208.51
# Part 223: starts machining at 208.51
# Part 219: finishes inspection at 208.66
# Part 219: good part produced at 208.66
# Part 220: starts inspection at 208.66
# Part 223: finishes machining at 209.17
# Part 218: starts machining at 209.17
# Part 220: finishes inspection at 209.44
# Part 220: good part produced at 209.44
# Part 221: starts inspection at 209.44
# Part 218: finishes machining at 209.87
# Part 224: starts machining at 209.87
# Part 221: finishes inspection at 210.23
# Part 221: good part produced at 210.23
# Part 222: starts inspection at 210.23
# Part 224: finishes machining at 210.53
# Part 225: starts machining at 210.53
# Part 222: finishes inspection at 211.01
# Part 222: good part produced at 211.01
# Part 223: starts inspection at 211.01
# Part 225: finishes machining at 211.22
# Part 226: starts machining at 211.55
# Part 223: finishes inspection at 211.78
# Part 223: good part produced at 211.78
# Part 218: starts inspection at 211.78
# Part 226: finishes machining at 212.24
# Part 227: starts machining at 212.24
# Part 218: finishes inspection at 212.57
# Part 218: good part produced at 212.57
# Part 224: starts inspection at 212.57
# Part 227: finishes machining at 212.94
# Part 228: starts machining at 212.94
# Part 224: finishes inspection at 213.37
# Part 224: good part produced at 213.37
# Part 225: starts inspection at 213.37
# Part 228: finishes machining at 213.63
# Part 229: starts machining at 213.63
# Part 225: finishes inspection at 214.12
# Part 225: good part produced at 214.12
# Part 226: starts inspection at 214.12
# Part 229: finishes machining at 214.31
# Part 230: starts machining at 214.31
# Part 226: finishes inspection at 214.90
# Part 226: good part produced at 214.90
# Part 227: starts inspection at 214.90
# Part 230: finishes machining at 214.99
# Part 231: starts machining at 214.99
# Part 231: finishes machining at 215.65
# Part 227: finishes inspection at 215.66
# Part 227: sent back for rework at 215.66
# Part 228: starts inspection at 215.66
# Part 227: starts machining at 215.66
# Part 227: finishes machining at 216.33
# Part 232: starts machining at 216.33
# Part 228: finishes inspection at 216.45
# Part 228: sent back for rework at 216.45
# Part 229: starts inspection at 216.45
# ...
# Part 440: finishes machining at 408.24
# Part 441: starts machining at 408.24
# Part 426: finishes inspection at 408.84
# Part 426: good part produced at 408.84
# Part 435: starts inspection at 408.84
# Part 441: finishes machining at 408.94
# Part 433: starts machining at 408.94
# Part 435: finishes inspection at 409.61
# Part 435: good part produced at 409.61
# Part 436: starts inspection at 409.61
# Part 433: finishes machining at 409.62
# Part 442: starts machining at 409.62
# Part 442: finishes machining at 410.28
# Part 436: finishes inspection at 410.39
# Part 436: good part produced at 410.39
# Part 437: starts inspection at 410.39
# Part 437: finishes inspection at 411.14
# Part 437: good part produced at 411.14
# Part 438: starts inspection at 411.14
# Part 443: starts machining at 411.87
# Part 438: finishes inspection at 411.91
# Part 438: good part produced at 411.91
# Part 439: starts inspection at 411.91
# Part 443: finishes machining at 412.55
# Part 444: starts machining at 412.55
# Part 439: finishes inspection at 412.69
# Part 439: good part produced at 412.69
# Part 440: starts inspection at 412.69
# Part 444: finishes machining at 413.21
# Part 440: finishes inspection at 413.48
# Part 440: good part produced at 413.48
# Part 441: starts inspection at 413.48
# Part 445: starts machining at 413.49
# Part 445: finishes machining at 414.17
# Part 446: starts machining at 414.17
# Part 441: finishes inspection at 414.26
# Part 441: good part produced at 414.26
# Part 433: starts inspection at 414.26
# Part 446: finishes machining at 414.83
# Part 447: starts machining at 414.83
# Part 433: finishes inspection at 415.02
# Part 433: good part produced at 415.02
# Part 442: starts inspection at 415.02
# Part 447: finishes machining at 415.53
# Part 448: starts machining at 415.53
# Part 442: finishes inspection at 415.78
# Part 442: good part produced at 415.78
# Part 443: starts inspection at 415.78
# Part 448: finishes machining at 416.22
# Part 449: starts machining at 416.22
# Part 443: finishes inspection at 416.54
# Part 443: good part produced at 416.54
# Part 444: starts inspection at 416.54
# Part 449: finishes machining at 416.87
# Part 450: starts machining at 416.87
# Part 444: finishes inspection at 417.31
# Part 444: good part produced at 417.31
# Part 445: starts inspection at 417.31
# Part 450: finishes machining at 417.57
# Part 451: starts machining at 417.57
# Part 445: finishes inspection at 418.07
# Part 445: good part produced at 418.07
# Part 446: starts inspection at 418.07
# Part 451: finishes machining at 418.26
# Part 452: starts machining at 418.26
# Part 446: finishes inspection at 418.83
# Part 446: good part produced at 418.83
# Part 447: starts inspection at 418.83
# Part 452: finishes machining at 418.92
# Part 453: starts machining at 418.92
# Part 453: finishes machining at 419.59
# Part 454: starts machining at 419.59
# Part 447: finishes inspection at 419.61
# Part 447: good part produced at 419.61
# Part 448: starts inspection at 419.61
# Hour 7: 67 parts produced.
# Part 454: finishes machining at 420.27
# Part 455: starts machining at 420.27
# Part 448: finishes inspection at 420.39
# Part 448: sent back for rework at 420.39
# Part 449: starts inspection at 420.39
# Part 455: finishes machining at 420.96
# Part 456: starts machining at 420.96
# Part 449: finishes inspection at 421.17
# Part 449: sent back for rework at 421.17
# Part 450: starts inspection at 421.17
# Part 456: finishes machining at 421.65
# Part 457: starts machining at 421.65
# Part 450: finishes inspection at 421.94
# Part 450: good part produced at 421.94
# Part 451: starts inspection at 421.94
# Part 457: finishes machining at 422.30
# Part 458: starts machining at 422.30
# Part 451: finishes inspection at 422.72
# Part 451: good part produced at 422.72
# Part 452: starts inspection at 422.72
# Part 458: finishes machining at 422.96
# Part 459: starts machining at 422.96
# Part 452: finishes inspection at 423.48
# Part 452: good part produced at 423.48
# Part 453: starts inspection at 423.48
# Part 459: finishes machining at 423.63
# Part 448: starts machining at 423.63
# Part 453: finishes inspection at 424.25
# Part 453: sent back for rework at 424.25
# Part 454: starts inspection at 424.25
# Part 448: finishes machining at 424.31
# Part 449: starts machining at 424.31
# Part 449: finishes machining at 425.00
# Part 460: starts machining at 425.00
# Part 454: finishes inspection at 425.02
# Part 454: good part produced at 425.02
# Part 455: starts inspection at 425.02
# Part 460: finishes machining at 425.67
# Part 461: starts machining at 425.67
# Part 455: finishes inspection at 425.81
# Part 455: good part produced at 425.81
# Part 456: starts inspection at 425.81
# Part 461: finishes machining at 426.35
# Part 462: starts machining at 426.35
# Part 456: finishes inspection at 426.56
# Part 456: sent back for rework at 426.56
# Part 457: starts inspection at 426.56
# Part 462: finishes machining at 427.05
# Part 463: starts machining at 427.05
# Part 457: finishes inspection at 427.36
# Part 457: good part produced at 427.36
# Part 458: starts inspection at 427.36
# Part 463: finishes machining at 427.70
# Part 464: starts machining at 427.70
# Part 458: finishes inspection at 428.15
# Part 458: good part produced at 428.15
# Part 459: starts inspection at 428.15
# Part 464: finishes machining at 428.39
# Part 465: starts machining at 428.39
# Part 459: finishes inspection at 428.93
# Part 459: good part produced at 428.93
# Part 448: starts inspection at 428.93
# Part 465: finishes machining at 429.06
# Part 453: starts machining at 429.06
# Part 448: finishes inspection at 429.70
# Part 448: good part produced at 429.70
# Part 449: starts inspection at 429.70
# Part 453: finishes machining at 429.75
# Part 466: starts machining at 429.75
# Part 466: finishes machining at 430.42
# Part 467: starts machining at 430.42
# Part 449: finishes inspection at 430.50
# Part 449: good part produced at 430.50
# Part 460: starts inspection at 430.50
# Part 467: finishes machining at 431.10
# Part 468: starts machining at 431.10
# Part 460: finishes inspection at 431.28
# Part 460: good part produced at 431.28
# Part 461: starts inspection at 431.28
# Part 468: finishes machining at 431.79
# Part 456: starts machining at 431.79
# Part 461: finishes inspection at 432.04
# Part 461: good part produced at 432.04
# Part 462: starts inspection at 432.04
# Part 456: finishes machining at 432.46
# Part 469: starts machining at 432.46
# Part 462: finishes inspection at 432.80
# Part 462: good part produced at 432.80
# Part 463: starts inspection at 432.80
# Part 469: finishes machining at 433.11
# Part 470: starts machining at 433.11
# Part 463: finishes inspection at 433.58
# Part 463: good part produced at 433.58
# Part 464: starts inspection at 433.58
# Part 470: finishes machining at 433.80
# Part 471: starts machining at 433.80
# Part 464: finishes inspection at 434.34
# Part 464: good part produced at 434.34
# Part 465: starts inspection at 434.34
# Part 471: finishes machining at 434.50
# Part 472: starts machining at 434.50
# Part 465: finishes inspection at 435.13
# Part 465: good part produced at 435.13
# Part 453: starts inspection at 435.13
# Part 472: finishes machining at 435.17
# Part 473: starts machining at 435.17
# Part 473: finishes machining at 435.82
# Part 474: starts machining at 435.82
# Part 453: finishes inspection at 435.93
# Part 453: good part produced at 435.93
# Part 466: starts inspection at 435.93
# Part 474: finishes machining at 436.51
# Part 475: starts machining at 436.51
# Part 466: finishes inspection at 436.68
# Part 466: good part produced at 436.68
# Part 467: starts inspection at 436.68
# Part 475: finishes machining at 437.19
# Part 476: starts machining at 437.19
# Part 467: finishes inspection at 437.44
# Part 467: good part produced at 437.44
# Part 468: starts inspection at 437.44
# Part 476: finishes machining at 437.85
# Part 477: starts machining at 437.85
# Part 468: finishes inspection at 438.21
# Part 468: good part produced at 438.21
# Part 456: starts inspection at 438.21
# Part 477: finishes machining at 438.54
# Part 478: starts machining at 438.54
# Part 456: finishes inspection at 438.97
# Part 456: good part produced at 438.97
# Part 469: starts inspection at 438.97
# Part 478: finishes machining at 439.22
# Part 479: starts machining at 439.22
# Part 469: finishes inspection at 439.76
# Part 469: good part produced at 439.76
# Part 470: starts inspection at 439.76
# Part 479: finishes machining at 439.88
# Part 480: starts machining at 439.88
# Part 470: finishes inspection at 440.52
# Part 470: good part produced at 440.52
# Part 471: starts inspection at 440.52
# Part 480: finishes machining at 440.54
# Part 481: starts machining at 440.54
# Part 481: finishes machining at 441.23
# Part 482: starts machining at 441.23
# Part 471: finishes inspection at 441.31
# Part 471: good part produced at 441.31
# Part 472: starts inspection at 441.31
# Part 482: finishes machining at 441.90
# Part 483: starts machining at 441.90
# Part 472: finishes inspection at 442.11
# Part 472: good part produced at 442.11
# Part 473: starts inspection at 442.11
# Part 483: finishes machining at 442.59
# Part 484: starts machining at 442.59
# Part 473: finishes inspection at 442.88
# Part 473: good part produced at 442.88
# Part 474: starts inspection at 442.88
# Part 484: finishes machining at 443.26
# Part 485: starts machining at 443.26
# Part 474: finishes inspection at 443.65
# Part 474: good part produced at 443.65
# Part 475: starts inspection at 443.65
# Part 485: finishes machining at 443.95
# Part 486: starts machining at 443.95
# Part 475: finishes inspection at 444.44
# Part 475: good part produced at 444.44
# Part 476: starts inspection at 444.44
# Part 486: finishes machining at 444.61
# Part 487: starts machining at 444.61
# Part 476: finishes inspection at 445.23
# Part 476: good part produced at 445.23
# Part 477: starts inspection at 445.23
# Part 487: finishes machining at 445.29
# Part 477: finishes inspection at 446.01
# Part 477: good part produced at 446.01
# Part 478: starts inspection at 446.01
# Part 478: finishes inspection at 446.77
# Part 478: good part produced at 446.77
# Part 479: starts inspection at 446.77
# Part 488: starts machining at 446.96
# Part 479: finishes inspection at 447.55
# Part 479: sent back for rework at 447.55
# Part 480: starts inspection at 447.55
# Part 488: finishes machining at 447.65
# Part 479: starts machining at 447.65
# Part 479: finishes machining at 448.31
# Part 480: finishes inspection at 448.34
# Part 480: good part produced at 448.34
# Part 481: starts inspection at 448.34
# Part 481: finishes inspection at 449.12
# Part 481: good part produced at 449.12
# Part 482: starts inspection at 449.12
# Part 489: starts machining at 449.51
# Part 482: finishes inspection at 449.92
# Part 482: good part produced at 449.92
# Part 483: starts inspection at 449.92
# Part 489: finishes machining at 450.20
# Part 490: starts machining at 450.20
# Part 483: finishes inspection at 450.69
# Part 483: good part produced at 450.69
# Part 484: starts inspection at 450.69
# Part 490: finishes machining at 450.89
# Part 491: starts machining at 451.01
# Part 484: finishes inspection at 451.49
# Part 484: good part produced at 451.49
# Part 485: starts inspection at 451.49
# Part 491: finishes machining at 451.71
# Part 492: starts machining at 451.71
# Part 485: finishes inspection at 452.29
# Part 485: good part produced at 452.29
# Part 486: starts inspection at 452.29
# Part 492: finishes machining at 452.38
# Part 486: finishes inspection at 453.07
# Part 486: good part produced at 453.07
# Part 487: starts inspection at 453.07
# Part 487: finishes inspection at 453.86
# Part 487: good part produced at 453.86
# Part 488: starts inspection at 453.86
# Part 493: starts machining at 454.30
# Part 488: finishes inspection at 454.65
# Part 488: good part produced at 454.65
# Part 479: starts inspection at 454.65
# Part 493: finishes machining at 454.97
# Part 494: starts machining at 454.97
# Part 479: finishes inspection at 455.42
# Part 479: good part produced at 455.42
# Part 489: starts inspection at 455.42
# Part 494: finishes machining at 455.65
# Part 495: starts machining at 455.65
# Part 489: finishes inspection at 456.17
# Part 489: good part produced at 456.17
# Part 490: starts inspection at 456.17
# Part 495: finishes machining at 456.32
# Part 490: finishes inspection at 456.97
# Part 490: good part produced at 456.97
# Part 491: starts inspection at 456.97
# Part 491: finishes inspection at 457.74
# Part 491: good part produced at 457.74
# Part 492: starts inspection at 457.74
# Part 492: finishes inspection at 458.50
# Part 492: good part produced at 458.50
# Part 493: starts inspection at 458.50
# Part 493: finishes inspection at 459.26
# Part 493: good part produced at 459.26
# Part 494: starts inspection at 459.26
# Part 496: starts machining at 459.48
# Part 494: finishes inspection at 460.04
# Part 494: good part produced at 460.04
# Part 495: starts inspection at 460.04
# Part 496: finishes machining at 460.13
# Part 497: starts machining at 460.13
# Part 497: finishes machining at 460.81
# Part 498: starts machining at 460.81
# Part 495: finishes inspection at 460.83
# Part 495: good part produced at 460.83
# Part 496: starts inspection at 460.83
# Part 498: finishes machining at 461.49
# Part 499: starts machining at 461.49
# Part 496: finishes inspection at 461.62
# Part 496: good part produced at 461.62
# Part 497: starts inspection at 461.62
# Part 499: finishes machining at 462.17
# Part 497: finishes inspection at 462.38
# Part 497: good part produced at 462.38
# Part 498: starts inspection at 462.38
# Part 498: finishes inspection at 463.14
# Part 498: good part produced at 463.14
# Part 499: starts inspection at 463.14
# Part 499: finishes inspection at 463.91
# Part 499: good part produced at 463.91
# Machine breaks down at 464.68
# Part 500: starts machining at 464.88
# Part 500: finishes machining at 465.53
# Part 500: starts inspection at 465.53
# Part 501: starts machining at 465.90
# Part 500: finishes inspection at 466.28
# Part 500: good part produced at 466.28
# Part 501: finishes machining at 466.60
# Part 501: starts inspection at 466.60
# Part 501: finishes inspection at 467.39
# Part 501: good part produced at 467.39
# Part 502: starts machining at 467.78
# Part 502: finishes machining at 468.44
# Part 502: starts inspection at 468.44
# Part 502: finishes inspection at 469.22
# Part 502: sent back for rework at 469.22
# Part 502: starts machining at 469.22
# Part 502: finishes machining at 469.90
# Part 503: starts machining at 469.90
# Part 502: starts inspection at 469.90
# Part 503: finishes machining at 470.58
# Part 504: starts machining at 470.58
# Part 502: finishes inspection at 470.68
# Part 502: good part produced at 470.68
# Part 503: starts inspection at 470.68
# Part 504: finishes machining at 471.26
# Part 505: starts machining at 471.26
# Part 503: finishes inspection at 471.46
# Part 503: good part produced at 471.46
# Part 504: starts inspection at 471.46
# Part 505: finishes machining at 471.91
# Part 506: starts machining at 471.91
# Part 504: finishes inspection at 472.22
# Part 504: good part produced at 472.22
# Part 505: starts inspection at 472.22
# Part 506: finishes machining at 472.56
# Part 507: starts machining at 472.56
# Part 505: finishes inspection at 473.01
# Part 505: good part produced at 473.01
# Part 506: starts inspection at 473.01
# Part 507: finishes machining at 473.25
# Part 506: finishes inspection at 473.76
# Part 506: sent back for rework at 473.76
# Part 507: starts inspection at 473.76
# Part 506: starts machining at 473.76
# Part 506: finishes machining at 474.42
# Part 507: finishes inspection at 474.52
# Part 507: good part produced at 474.52
# Part 506: starts inspection at 474.52
# Part 506: finishes inspection at 475.31
# Part 506: good part produced at 475.31
# Part 508: starts machining at 475.65
# Part 508: finishes machining at 476.32
# Part 509: starts machining at 476.32
# Part 508: starts inspection at 476.32
# Part 509: finishes machining at 476.99
# Part 510: starts machining at 476.99
# Part 508: finishes inspection at 477.10
# Part 508: good part produced at 477.10
# Part 509: starts inspection at 477.10
# Part 510: finishes machining at 477.66
# Part 509: finishes inspection at 477.89
# Part 509: good part produced at 477.89
# Part 510: starts inspection at 477.89
# Part 510: finishes inspection at 478.69
# Part 510: good part produced at 478.69
# Hourly production counts: [60, 56, 71, 66, 69, 58, 67]
